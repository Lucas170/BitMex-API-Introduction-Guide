# %%
import bitmex
import datetime
import requests

# %%
client = bitmex.bitmex()
result = client.Quote.Quote_get(symbol="XBTUSD", reverse=True, count=1).result()
result[0][0]['bidPrice']
# Out:
# C:\Users\igorr\anaconda3\lib\site-packages\swagger_spec_validator\validator20.py:49: SwaggerValidationWarning: Found "$ref: #/definitions/UserPreferences" with siblings that will be overwritten. See https://stackoverflow.com/a/48114924 for more information. (path #/definitions/User/properties/preferences)
#   warnings.warn(
# 14095.0

# %%
result[0][0]['bidSize']
# Out:
# 644

# %%
result[0][0]['askPrice']
# Out:
# 14095.5

# %%
client.Quote.Quote_get(symbol="XBTUSD", endTime=datetime.datetime.utcnow()).result()
# Out:
# ([{'timestamp': datetime.datetime(2020, 11, 3, 8, 46, 18, 886000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3594,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 33317},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 46, 20, 283000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3594,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 33117},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 0, 270000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3594,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32995},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 0, 488000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32995},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 1, 665000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32873},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 20, 24000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32871},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 21, 424000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32869},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 34, 228000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32859},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 48, 35, 634000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3644,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32849},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 49, 7, 217000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3634,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32849},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 50, 54, 464000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3512,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32849},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 53, 16, 927000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3512,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32859},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 54, 29, 32000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3512,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32857},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 54, 30, 471000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3512,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32855},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 56, 40, 981000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4012,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 32855},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 58, 45, 462000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4012,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 31855},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 58, 46, 963000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4012,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 30855},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 58, 57, 505000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4012,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 30845},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 30, 296000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3012,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 30845},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 32, 154000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2837,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 30845},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 32, 207000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2072,
#    'bidPrice': 13472.5,
#    'askPrice': 13473.0,
#    'askSize': 30845},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 36, 283000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2072,
#    'bidPrice': 13472.5,
#    'askPrice': 13504.5,
#    'askSize': 200},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 36, 306000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 300,
#    'bidPrice': 13473.0,
#    'askPrice': 13504.5,
#    'askSize': 200},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 36, 340000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1492,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 200},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 36, 439000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1992,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 200},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 37, 346000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1992,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 251},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 38, 733000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1992,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 314},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 39, 159000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1992,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 377},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 40, 483000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1992,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11871},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 41, 26000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2022,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11871},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 41, 131000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2022,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11901},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 41, 696000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2022,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11838},
#   {'timestamp': datetime.datetime(2020, 11, 3, 8, 59, 48, 34000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2747,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11838},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 7, 362000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2747,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11355},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 7, 972000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2747,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 11027},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 8, 821000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2747,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10530},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 14, 69000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2991,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10530},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 20, 291000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3127,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10530},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 21, 692000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3127,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 25, 794000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3135,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 29, 948000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3271,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 34, 934000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3407,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 36, 227000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1700,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 40, 36000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3749,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 40, 195000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3885,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 58, 864000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3835,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 0, 59, 959000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4282,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10680},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 1, 18, 993000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4282,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10816},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 1, 45, 175000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4292,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10816},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 21, 649000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4292,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10566},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 23, 48000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4292,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10316},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 33, 308000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4292,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10216},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 34, 638000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4192,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10216},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 34, 713000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4192,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 38, 161000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4192,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 10016},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 38, 399000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 4192,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9816},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 39, 521000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3892,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9816},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 39, 591000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3892,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9516},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 40, 34000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3739,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9516},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 42, 86000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3769,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9516},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 42, 428000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3769,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9416},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 43, 110000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3669,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9416},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 43, 830000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3669,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9316},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 43, 988000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3669,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9216},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 44, 228000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3569,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9216},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 45, 247000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3569,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 47, 719000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3319,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 2, 48, 29000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2981,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 3, 7, 557000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2991,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 4, 1, 390000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2981,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 4, 7, 328000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2961,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 4, 47, 188000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2861,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 9116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 5, 0, 870000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2861,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 8116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 5, 2, 281000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 2861,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 7116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 5, 5, 453000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3361,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 7116},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 5, 23, 492000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3361,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 6980},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 0, 864000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3361,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 6820},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 2, 279000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3361,
#    'bidPrice': 13504.0,
#    'askPrice': 13504.5,
#    'askSize': 6660},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 17, 319000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 3361,
#    'bidPrice': 13504.0,
#    'askPrice': 13505.5,
#    'askSize': 156},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 17, 343000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 300,
#    'bidPrice': 13504.5,
#    'askPrice': 13505.5,
#    'askSize': 156},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 17, 545000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1559,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 156},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 19, 335000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1559,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 126},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 19, 767000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1559,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 156},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 19, 830000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1559,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 2027},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 21, 758000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1567,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 2027},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 24, 382000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1703,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 2027},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 27, 166000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1603,
#    'bidPrice': 13505.0,
#    'askPrice': 13505.5,
#    'askSize': 2027},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 29, 560000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1603,
#    'bidPrice': 13505.0,
#    'askPrice': 13506.5,
#    'askSize': 2},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 29, 634000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1384,
#    'bidPrice': 13506.0,
#    'askPrice': 13506.5,
#    'askSize': 2},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 31, 21000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1392,
#    'bidPrice': 13506.0,
#    'askPrice': 13506.5,
#    'askSize': 2},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 35, 46000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1422,
#    'bidPrice': 13506.0,
#    'askPrice': 13506.5,
#    'askSize': 2},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 35, 111000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1422,
#    'bidPrice': 13506.0,
#    'askPrice': 13506.5,
#    'askSize': 642},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 35, 172000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1422,
#    'bidPrice': 13506.0,
#    'askPrice': 13506.5,
#    'askSize': 672},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 41, 705000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1422,
#    'bidPrice': 13506.0,
#    'askPrice': 13509.5,
#    'askSize': 10},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 41, 709000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1422,
#    'bidPrice': 13506.0,
#    'askPrice': 13531.5,
#    'askSize': 73},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 41, 840000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1384,
#    'bidPrice': 13531.0,
#    'askPrice': 13531.5,
#    'askSize': 73},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 42, 933000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1392,
#    'bidPrice': 13531.0,
#    'askPrice': 13531.5,
#    'askSize': 73},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 43, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1392,
#    'bidPrice': 13531.0,
#    'askPrice': 13531.5,
#    'askSize': 117},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 43, 701000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1392,
#    'bidPrice': 13531.0,
#    'askPrice': 13531.5,
#    'askSize': 161},
#   {'timestamp': datetime.datetime(2020, 11, 3, 9, 9, 43, 889000, tzinfo=tzutc()),
#    'symbol': 'XBTUSD',
#    'bidSize': 1528,
#    'bidPrice': 13531.0,
#    'askPrice': 13531.5,
#    'askSize': 161}],
#  <bravado.requests_client.RequestsResponseAdapter at 0x233eb2632b0>)
